# %%
import plotly.express as px
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# %%
x = [1,2,3,4,5,6,7]
y =[10,11,12,13,14,15,16]
kk = px.line(x=x, y=y, title='Simple Line Plot')
